# %%
import cv2

# %%
img= cv2.imread('goblin.jpg')
img.shape
# Out:
# (800, 1280, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img)

# %%
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (800, 1280)

# %%
plt.imshow(gray, cmap='gray')

# %%
gray
# Out:
# array([[217, 217, 217, ..., 222, 222, 222],
#        [217, 217, 217, ..., 222, 222, 222],
#        [217, 217, 217, ..., 222, 222, 222],
#        ...,
#        [153, 153, 152, ..., 152, 152, 152],
#        [154, 154, 153, ..., 152, 153, 153],
#        [154, 154, 153, ..., 153, 153, 153]], dtype=uint8)
